# %%
import pandas as pd
import geopandas as gp
import matplotlib.pyplot as plt
from descartes import PolygonPatch
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
import matplotlib.patheffects as PathEffects
from shapely.geometry.multipolygon import MultiPolygon
from shapely.geometry.multilinestring import MultiLineString
from matplotlib.collections import LineCollection
import numpy as np
import biv_colormap as bc
import plotly.graph_objs as go
from matplotlib import colors

# %%
#Load gini index and average income data
pph_raw = pd.read_csv('pay_per_hour/average_pph_male_female.csv')
#income_raw = pd.read_csv('av_income_italy_2017.csv')
#Load shapefile from file
df = gp.read_file("shapefiles/Com01012019_g_WGS84.shp")

# %%
average_pph = pph_raw[pph_raw['TIPO_DATO7'] == "HOUWAG_ENTEMP_AV_MI"]

# %%
code_comune = df[['COD_PROV','COMUNE']]

# %%
code_comune[code_comune['COD_PROV']==103]
# Out:
#       COD_PROV              COMUNE
# 6678       103  Antrona Schieranco
# 6679       103     Anzola d'Ossola
# 6680       103              Masera
# 6681       103            Massiola
# 6682       103            Mergozzo
# ...        ...                 ...
# 7140       103            Intragna
# 7141       103            Loreglia
# 7142       103           Macugnaga
# 7143       103   Madonna del Sasso
# 7144       103             Malesco
#
# [74 rows x 2 columns]

# %%
average_pph
# Out:
#      ITTER107            Territorio           TIPO_DATO7  \
# 26      ITC12              Vercelli  HOUWAG_ENTEMP_AV_MI
# 29      ITC13                Biella  HOUWAG_ENTEMP_AV_MI
# 32      ITC14  Verbano-Cusio-Ossola  HOUWAG_ENTEMP_AV_MI
# 38      ITC15                Novara  HOUWAG_ENTEMP_AV_MI
# 41      ITC16                 Cuneo  HOUWAG_ENTEMP_AV_MI
# ...       ...                   ...                  ...
# 1592    ITG26                 Nuoro  HOUWAG_ENTEMP_AV_MI
# 1594       IT                Italia  HOUWAG_ENTEMP_AV_MI
# 1597    IT111          Sud Sardegna  HOUWAG_ENTEMP_AV_MI
# 1602    IT111          Sud Sardegna  HOUWAG_ENTEMP_AV_MI
# 1607    IT111          Sud Sardegna  HOUWAG_ENTEMP_AV_MI
#
#                                               Tipo dato  SEXISTAT1    Sesso  \
# 26    Retribuzione lorda oraria per ora retribuita d...          9   totale
# 29    Retribuzione lorda oraria per ora retribuita d...          2  femmine
# ...

# %%
# Out:
#       COD_RIP  COD_REG  COD_PROV  COD_CM  COD_UTS  PRO_COM PRO_COM_T  \
# 0           1        1         2       0        2     2031    002031
# 1           1        1         2       0        2     2032    002032
# 2           1        1         2       0        2     2033    002033
# 3           1        1         2       0        2     2035    002035
# 4           1        1         2       0        2     2041    002041
# ...       ...      ...       ...     ...      ...      ...       ...
# 7921        5       20        91       0       91    91017    091017
# 7922        5       20        91       0       91    91018    091018
# 7923        5       20        91       0       91    91019    091019
# 7924        5       20        91       0       91    91024    091024
# 7925        5       20        91       0       91    91025    091025
#
#                       COMUNE COMUNE_A  CC_UTS    Shape_Leng    Shape_Area  \
# ...
